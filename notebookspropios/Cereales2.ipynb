# %%
import pandas as pd
import os
import numpy as np

# %%
a = list(pd.read_csv("C:/Users/Guany/Documents/GitHub/python-ml-course/datasets/cereals/Cereal data columns.csv", header = None, index_col = 0).transpose())
a.append("Cups per serving")
a[0]= "Cereal name"
a
# Out:
# ['Cereal name',
#  'Manufacturer',
#  'Type',
#  'Calories',
#  'Protein',
#  'Fat',
#  'Sodium',
#  'Dietary Fiber',
#  'Complex Carbohydrates',
#  'Sugar ',
#  'Display Shelf',
#  'Potassium',
#  'Vitamins & Minerals',
#  'Weight',
#  'Cups per serving']

# %%
b = pd.read_csv("C:/Users/Guany/Documents/GitHub/python-ml-course/datasets/cereals/Cereal data.txt", sep=" ", names=a, index_col = "Cereal name")
print(b.shape)
# Out:
# (77, 14)

# %%
b
# Out:
#                                        Manufacturer Type  Calories  Protein  \
# Cereal name
# 100%_Bran                                         N    C        70        4
# 100%_Natural_Bran                                 Q    C       120        3
# All-Bran                                          K    C        70        4
# All-Bran_with_Extra_Fiber                         K    C        50        4
# Almond_Delight                                    R    C       110        2
# Apple_Cinnamon_Cheerios                           G    C       110        2
# Apple_Jacks                                       K    C       110        2
# Basic_4                                           G    C       130        3
# Bran_Chex                                         R    C        90        2
# Bran_Flakes                                       P    C        90        3
# Cap'n'Crunch                                      Q    C       120        1
# ...
