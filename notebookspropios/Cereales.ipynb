# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cabecera = "C:/Users/Guany/Documents/GitHub/python-ml-course/datasets/cereals/Cereal data columns.csv"
datos = "C:/Users/Guany/Documents/GitHub/python-ml-course/datasets/cereals/Cereal data.txt"

# %%
data_cols = pd.read_csv(cabecera)

# %%
data_cols
# Out:
#                    Cereal
# 0            Manufacturer
# 1                    Type
# 2                Calories
# 3                 Protein
# 4                     Fat
# 5                  Sodium
# 6           Dietary Fiber
# 7   Complex Carbohydrates
# 8                  Sugar
# 9           Display Shelf
# 10              Potassium
# 11    Vitamins & Minerals
# 12                 Weight

# %%
data_col_list = data_cols["Cereal"].tolist()
data2= pd.read_csv(datos, header=None, names={"Name", "Manufacturer", "Type", "Calories", "Protein", "Fat", "Sodium", "Fiber", "Carbo", "Sugars", "Potass", "Vitamins", "Weight", "Cups"} , sep= " ")
data2.columns.values
# Out:
# array(['Protein', 'Name', 'Weight', 'Sugars', 'Fiber', 'Sodium', 'Fat',
#        'Type', 'Carbo', 'Vitamins', 'Cups', 'Manufacturer', 'Calories',
#        'Potass'], dtype=object)

# %%
data2.head()
# Out:
#                           Protein Name  Weight  Sugars  Fiber  Sodium   Fat  \
# 100%_Bran                       N    C      70       4      1     130  10.0
# 100%_Natural_Bran               Q    C     120       3      5      15   2.0
# All-Bran                        K    C      70       4      1     260   9.0
# All-Bran_with_Extra_Fiber       K    C      50       4      0     140  14.0
# Almond_Delight                  R    C     110       2      2     200   1.0
#
#                            Type  Carbo  Vitamins  Cups  Manufacturer  \
# 100%_Bran                   5.0      6         3   280            25
# 100%_Natural_Bran           8.0      8         3   135             0
# All-Bran                    7.0      5         3   320            25
# All-Bran_with_Extra_Fiber   8.0      0         3   330            25
# Almond_Delight             14.0      8         3    -1            25
#
#                            Calories  Potass
# 100%_Bran                       1.0    0.33
# 100%_Natural_Bran               1.0   -1.00
# All-Bran                        1.0    0.33
# All-Bran_with_Extra_Fiber       1.0    0.50
# Almond_Delight                  1.0    0.75
